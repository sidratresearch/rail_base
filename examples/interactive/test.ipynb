# %%
from rail import hello

# %%
from rail import interactive as interact
import matplotlib.pyplot

# %%
interact.creation.degraders.addRandom.aaa_fake_stage

# %%
matplotlib.pyplot.Figure
